# %%
import tensorflow as tf
keras = tf.keras

# %%
actor = keras.models.load_model('saved_models/actor-continuous-2022-03-07 18:44:11.742029')
# Out:
# Metal device set to: Apple M1 Max
# 2022-03-08 17:48:55.797989: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-08 17:48:55.798100: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(actor)

# %%
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]

# %%
tflite_model = converter.convert()
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# 2022-03-08 17:49:39.314103: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /var/folders/hn/tndm9dyn3dd0xbtnwgv3m9cr0000gn/T/tmpzo1pm8nl/assets
# INFO:tensorflow:Assets written to: /var/folders/hn/tndm9dyn3dd0xbtnwgv3m9cr0000gn/T/tmpzo1pm8nl/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# 2022-03-08 17:49:40.707601: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# ...

# %%
tflite_model
# Out:
# b'$\x00\x00\x00TFL3\x00\x00\x00\x00\x00\x00\x00\x00\x14\x00 \x00\x04\x00\x08\x00\x0c\x00\x10\x00\x14\x00\x00\x00\x18\x00\x1c\x00\x14\x00\x00\x00\x03\x00\x00\x00($\x00\x00\xb8\x1a\x00\x00\xa0\x1a\x00\x00\xac\x00\x00\x00t\x00\x00\x00\x04\x00\x00\x00\x01\x00\x00\x00\x04\x00\x00\x00>\xe3\xff\xffD\x00\x00\x00\x1c\x00\x00\x00\x04\x00\x00\x00\x0f\x00\x00\x00serving_default\x00\x01\x00\x00\x00\x04\x00\x00\x00\xc0\xff\xff\xff\x08\x00\x00\x00\x14\x00\x00\x00\x0b\x00\x00\x00concatenate\x00\x01\x00\x00\x00\x04\x00\x00\x00\x1e\xe5\xff\xff\x04\x00\x00\x00\x07\x00\x00\x00input_1\x00\x01\x00\x00\x00\x0c\x00\x00\x00\x08\x00\x0c\x00\x04\x00\x08\x00\x08\x00\x00\x00\x08\x00\x00\x00\x16\x00\x00\x00\x13\x00\x00\x00min_runtime_version\x00\x17\x00\x00\x00\xe4\x19\x00\x00\xd0\x19\x00\x00\xb4\x19\x00\x00\x90\x19\x00\x00|\x18\x00\x00h\x17\x00\x00T\x15\x00\x00@\x05\x00\x00,\x03\x00\x00\x18\x01\x00\x00\x04\x01\x00\x00\xf8\x00\x00\x00\xe4\x00\x00\x00\xd0\x00\x00\x00\xbc\x00\x00\x00\xa8\x00\x00\x00\x94\x00\x00\x00
# ...

# %%
open('actor.tflite','wb').write(tflite_model)
# Out:
# 9424
